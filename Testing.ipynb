# %%
import librosa
from notebook_tools import *
import unit_conversion as uc

import warnings
warnings.filterwarnings('ignore')

# %%
sample_name = 'Sample 95.m4a'

audio, sampling_rate = librosa.load(f'./data/audio/{sample_name}')

print(sampling_rate)

print(audio.shape)
# Out:
# 22050
# (995367,)

# %%
plot_audio_sample(audio, sampling_rate, title=sample_name, time_range=(35000,35500), units='ms')
