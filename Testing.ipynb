# %%
import rhythm_regression.notebook_tools as nbt

import librosa
# import librosa.display
# import IPython.display as ipd

import warnings
warnings.filterwarnings('ignore')

# %%
sample_name = 'Sample 1.m4a'
sample_path = f'./data/audio/{sample_name}'

# ipd.Audio(filename=sample_path)

# %%
audio, sampling_rate = librosa.load(sample_path)

print(sampling_rate)

print(audio.shape)
# Out:
# 22050
# (663735,)

# %%
nbt.plot_signal(audio, title=sample_name, units='samples', time_range=(20000,30000))
# Out:
# <AxesSubplot:title={'center':'Sample 1.m4a (Sampled at 22050 Hz)'}, xlabel='Samples'>

# %%
nbt.plot_amplitude_envelope(audio, title=sample_name, units='samples', time_range=(0,50000))
# Out:
# <AxesSubplot:title={'center':'Sample 1.m4a (Sampled at 22050 Hz)'}, xlabel='Samples'>
