# %%
import rhythm_regression.notebook_tools as nbt

import librosa
import numpy as np
from tqdm import tqdm

import warnings
warnings.filterwarnings('ignore')

# %%
samples = np.array([librosa.load(f'./data/audio/Sample {sample_id}.m4a')[0] for sample_id in tqdm(range(1,101))])
print([audio.shape for audio in samples])
# Out:
# 100%|██████████| 100/100 [02:25<00:00,  1.46s/it]
# ...

# %%
#for i in range(len(samples)):
    #nbt.plot_rmse_transients(samples[i], title=f'Sample {i+1}')

# %%
nbt.plot_rmse_transients(samples[99-1], time_range=(0,120), title='Sample 9')
# Out:
# <AxesSubplot:title={'center':'Sample 9'}, xlabel='Time (s)'>

# %%
nbt.plot_rmse_transients(samples[16-1], time_range=(30, 40), title='Sample 16')
# missing note due to player mistake
# Out:
# <AxesSubplot:title={'center':'Sample 16'}, xlabel='Time (s)'>

# %%
nbt.plot_rmse_transients(samples[31-1], time_range=(25,35), title='Sample 31')
# perfect
# Out:
# <AxesSubplot:title={'center':'Sample 31'}, xlabel='Time (s)'>

# %%
nbt.plot_rmse_transients(samples[32-1], time_range=(25,35), title='Sample 32')
# perfect
# Out:
# <AxesSubplot:title={'center':'Sample 32'}, xlabel='Time (s)'>

# %%
nbt.plot_rmse_transients(samples[33-1], time_range=(0,60), title='Sample 33')
# extra transient and missing transient cancel out
# Out:
# <AxesSubplot:title={'center':'Sample 33'}, xlabel='Time (s)'>

# %%
nbt.plot_rmse_transients(samples[34-1], time_range=(25,35), title='Sample 34')
# perfect
# Out:
# <AxesSubplot:title={'center':'Sample 34'}, xlabel='Time (s)'>

# %%
nbt.plot_rmse_transients(samples[35-1], time_range=(25,35), title='Sample 35')
# perfect
# Out:
# <AxesSubplot:title={'center':'Sample 35'}, xlabel='Time (s)'>

# %%
nbt.plot_rmse_transients(samples[56-1], time_range=(20,25), title='Sample 56')
# Out:
# <AxesSubplot:title={'center':'Sample 56'}, xlabel='Time (s)'>

# %%
for start_time in range(0, 40, 5):
    nbt.plot_rmse_transients(samples[69-1], time_range=(start_time, start_time+5), title='Sample 69')
# missing diddles at 22, and 37-38 seconds

# %%
for start_time in range(0, 45, 5):
    nbt.plot_rmse_transients(samples[86-1], time_range=(start_time, start_time+5), title='Sample 86')
